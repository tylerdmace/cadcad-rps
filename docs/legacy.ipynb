# %%
import sys
sys.path.append("/home/jovyan/cadcad-rps")
from cadCAD.engine import ExecutionMode, ExecutionContext, Executor
from model.config import exp
import pandas as pd

data, tensor_field, sessions = Executor(exec_context=ExecutionContext(context=ExecutionMode().local_mode), configs=exp.configs).execute()
# Out:
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# cadCAD Version: 0.4.28
# Execution Mode: local_proc
# Simulation Dimensions:
# Entire Simulation: (Models, Unique Timesteps, Params, Total Runs, Sub-States) = (1, 10, 0, 100, 2)
#      Simulation 0: (Timesteps, Params, Runs, Sub-States) = (10, 0, 100, 2)
# Execution Method: local_simulations
# Execution Mode: parallelized
# Total execution time: 10.23s

# %%
pd.DataFrame(data)
# Out:
#       box_A  box_B  simulation  subset  run  substep  timestep
# 0        10      0           0       0    1        0         0
# 1         9      1           0       0    1        1         1
# 2         8      2           0       0    1        1         2
# 3         7      3           0       0    1        1         3
# 4         6      4           0       0    1        1         4
# ...     ...    ...         ...     ...  ...      ...       ...
# 1095      5      5           0       0  100        1         6
# 1096      5      5           0       0  100        1         7
# 1097      5      5           0       0  100        1         8
# 1098      5      5           0       0  100        1         9
# 1099      5      5           0       0  100        1        10
#
# [1100 rows x 7 columns]
